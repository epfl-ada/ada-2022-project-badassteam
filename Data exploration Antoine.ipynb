# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math


movies = pd.read_table('movie.metadata.tsv',names=['Wiki_ID','Freebase_ID','Name','Release_Date','Box_Office_Revenue','Length','language','Country','Genre'])
characters = pd.read_table('character.metadata.tsv', names=['Wiki_ID','Freebase_ID','Release_Date','Name','Actor_Date_Of_Birth','Actor_Gender','Actor_Height','Actor_Ethnicity','Actor_Name','Actor_Age_At_Release','Freebase_Map','Freebase_Character_ID','Freebase_Actor_ID'])
#name = pd.read_csv('name.clusters.txt', sep="  ")
#summaries = pd.read_csv('plot_summaries.txt', sep=" ")

movies
# Out:
#         Wiki_ID Freebase_ID  \
# 0        975900   /m/03vyhn
# 1       3196793   /m/08yl5d
# 2      28463795  /m/0crgdbh
# 3       9363483  /m/0285_cd
# 4        261236   /m/01mrr1
# ...         ...         ...
# 81736  35228177  /m/0j7hxnt
# 81737  34980460  /m/0g4pl34
# 81738   9971909  /m/02pygw1
# 81739    913762   /m/03pcrp
# 81740  12476867  /m/02w7zz8
#
#                                                     Name Release_Date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                            Brun bitter         1988
# 3                                       White Of The Eye         1987
# 4                                      A Woman in Flames         1983
# ...                                                  ...          ...
# 81736                           Mermaids: The Body Found   2011-03-19
# 81737                                            Knuckle   2011-01-21
# 81738                                  Another Nice Mess   1972-09-22
# 81739  The Super Dimension Fortress Macross II: Lover...   1992-05-21
# 81740                                            Spliced         2002
#
#        Box_Office_Revenue  Length                            language  \
# 0              14010832.0    98.0  {"/m/02h40lc": "English Language"}
# 1                     NaN    95.0  {"/m/02h40lc": "English Language"}
# 2                     NaN    83.0  {"/m/05f_3": "Norwegian Language"}
# 3                     NaN   110.0  {"/m/02h40lc": "English Language"}
# 4                     NaN   106.0   {"/m/04306rv": "German Language"}
# ...                   ...     ...                                 ...
# 81736                 NaN   120.0  {"/m/02h40lc": "English Language"}
# 81737                 NaN    96.0  {"/m/02h40lc": "English Language"}
# 81738                 NaN    66.0  {"/m/02h40lc": "English Language"}
# 81739                 NaN   150.0   {"/m/03_9r": "Japanese Language"}
# 81740                 NaN    86.0  {"/m/02h40lc": "English Language"}
#
#                                                  Country  \
# 0              {"/m/09c7w0": "United States of America"}
# 1              {"/m/09c7w0": "United States of America"}
# 2                                 {"/m/05b4w": "Norway"}
# 3                         {"/m/07ssc": "United Kingdom"}
# 4                                {"/m/0345h": "Germany"}
# ...                                                  ...
# 81736          {"/m/09c7w0": "United States of America"}
# 81737  {"/m/03rt9": "Ireland", "/m/07ssc": "United Ki...
# 81738          {"/m/09c7w0": "United States of America"}
# 81739                              {"/m/03_3d": "Japan"}
# 81740                            {"/m/0d060g": "Canada"}
#
#                                                    Genre
# 0      {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1      {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2      {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3      {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                                {"/m/07s9rl0": "Drama"}
# ...                                                  ...
# 81736                            {"/m/07s9rl0": "Drama"}
# 81737  {"/m/03bxz7": "Biographical film", "/m/07s9rl0...
# 81738       {"/m/06nbt": "Satire", "/m/01z4y": "Comedy"}
# 81739  {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...
# 81740  {"/m/01jfsb": "Thriller", "/m/03npn": "Horror"...
#
# [81741 rows x 9 columns]

# %%
a=pd.DataFrame(characters[characters.Actor_Name=='Scarlett Johansson']['Wiki_ID'])
a
# Out:
#          Wiki_ID
# 6817    22144721
# 6838    22144721
# 11665   11723307
# 14984    1599839
# 56043    5959715
# 74406   20179720
# 93284    5649318
# 147852   2706589
# 158116   1960065
# 164866   3524655
# 170194   1189614
# 203540   2032945
# 205845   2529009
# 207903  29373289
# 217762  10780993
# 235465    369682
# 252366   4410141
# 278745    956388
# 309312    939203
# 321825   1068520
# 333452    695249
# 347198    970386
# 348272   6340115
# 364017   1195543
# 369930   6961461
# 371369  22114132
# 371370  22114132
# 376336    601923
# 379139   6029546
# 382967    698969
# 383808  13229264
# 402107   2809621
# 414491    241052

# %%
movies[movies.Name=='Batman']
# Out:
#        Wiki_ID Freebase_ID    Name Release_Date  Box_Office_Revenue  Length  \
# 4253      4727    /m/01hpp  Batman   1966-07-30                 NaN   104.0
# 22790  8915540  /m/027phbc  Batman         1943                 NaN     NaN
# 55165     4726    /m/01hp5  Batman   1989-06-19         411348924.0   126.0
#
#                                                 language  \
# 4253                  {"/m/02h40lc": "English Language"}
# 22790                 {"/m/02h40lc": "English Language"}
# 55165  {"/m/064_8sq": "French Language", "/m/02h40lc"...
#
#                                                  Country  \
# 4253           {"/m/09c7w0": "United States of America"}
# 22790          {"/m/09c7w0": "United States of America"}
# 55165  {"/m/09c7w0": "United States of America", "/m/...
#
#                                                    Genre
# 4253   {"/m/0gf28": "Parody", "/m/04pbhw": "Superhero...
# 22790  {"/m/05swd": "Propaganda film", "/m/01g6gs": "...
# 55165  {"/m/0lsxr": "Crime Fiction", "/m/01jfsb": "Th...

# %%
characters[characters.Name=='Batman']
# Out:
#          Wiki_ID Freebase_ID Release_Date    Name Actor_Date_Of_Birth  \
# 25371   16902911  /m/0411ph8         2007  Batman                 NaN
# 35948   26340083  /m/0bbxwx5   2010-07-27  Batman          1956-08-12
# 47853   24353804  /m/07s7m20         2010  Batman          1963-02-21
# 63399     162147   /m/015j5s   1967-06-03  Batman          1941-09-17
# 63694   29075630  /m/0bpm4yw   2012-07-16  Batman          1974-01-30
# 81711    7359078   /m/0kv5vz   2005-05-05  Batman          1968-11-05
# 94576       4730    /m/01hr1   1995-06-09  Batman          1959-12-31
# 153462    311765   /m/01t8m2   1993-12-25  Batman          1955-11-30
# 189697   5683113   /m/0dzz6g   2003-01-20  Batman                 NaN
# 231733  29097142  /m/0dlk_qn   2013-01-25  Batman          1975-09-18
# 239783  33240946  /m/0hy_s2x   2012-02-28  Batman          1955-11-30
# 245835  17726219  /m/0479qny   2008-08-29  Batman          1977-02-18
# 292904      4729    /m/01hqk   1997-06-12  Batman          1961-05-06
# 293012      4728    /m/01hq1   1992-06-16  Batman          1951-09-05
# 312456   4056040   /m/0bfvwf   2005-03-12  Batman          1949-05-24
# 320117   4276475   /m/0btpm6   2008-07-16  Batman          1974-01-30
# 377615      4726    /m/01hp5   1989-06-19  Batman          1951-09-05
# 377796      4727    /m/01hpp   1966-07-30  Batman          1928-09-19
# 399601   6203432   /m/0fwlk8      2005-01  Batman          1928-09-19
# 438522   5555253   /m/0dsb4b   1999-05-14  Batman          1964-04-25
# 439669  13375677  /m/0h51wq9   2011-10-18  Batman          1978-09-12
# 441236    481605   /m/02fqrf   2005-06-10  Batman          1974-01-30
#
#        Actor_Gender  Actor_Height Actor_Ethnicity         Actor_Name  \
# 25371           NaN           NaN             NaN      Maxwell Allen
# 35948             M          1.80      /m/044038p    Bruce Greenwood
# 47853             M          1.87             NaN    William Baldwin
# 63399             M           NaN             NaN        Jing Abalos
# 63694             M          1.83       /m/02w7gg     Christian Bale
# 81711             M          1.75             NaN       Sam Rockwell
# 94576             M          1.83       /m/07bch9         Val Kilmer
# 153462            M           NaN             NaN       Kevin Conroy
# 189697            M           NaN             NaN        Joe Krajcar
# 231733            M          1.85       /m/02ctzb     Jason Sudeikis
# 239783            M           NaN             NaN       Kevin Conroy
# 245835            M           NaN             NaN     Ike Barinholtz
# 292904            M          1.80       /m/033tf_     George Clooney
# 293012            M          1.78       /m/07bch9     Michael Keaton
# 312456            M          1.87       /m/02w7gg      Jim Broadbent
# 320117            M          1.83       /m/02w7gg     Christian Bale
# 377615            M          1.78       /m/07bch9     Michael Keaton
# 377796            M          1.88             NaN          Adam West
# 399601            M          1.88             NaN          Adam West
# 438522            M          1.91             NaN        Vince Offer
# 439669            M          1.74             NaN  Benjamin McKenzie
# 441236            M          1.83       /m/02w7gg     Christian Bale
#
#         Actor_Age_At_Release Freebase_Map Freebase_Character_ID  \
# 25371                    NaN   /m/0h0zm5m              /m/01d5g
# 35948                   53.0   /m/0bd46jp              /m/01d5g
# 47853                   46.0   /m/07ss96y              /m/01d5g
# 63399                   25.0   /m/03jp7wh              /m/01d5g
# 63694                   38.0   /m/0bpm5w7              /m/01d5g
# 81711                   36.0   /m/02vcbgg              /m/01d5g
# 94576                   35.0   /m/02wk6fh              /m/01d5g
# 153462                  38.0    /m/0jv2nh              /m/01d5g
# 189697                   NaN   /m/0gj68df              /m/01d5g
# 231733                  37.0   /m/0gyl22z              /m/01d5g
# 239783                  56.0   /m/0j2ps42              /m/01d5g
# 245835                  31.0   /m/0hgzjcb              /m/01d5g
# 292904                  36.0    /m/0jv293              /m/01d5g
# 293012                  40.0   /m/02wk6f4              /m/01d5g
# 312456                  55.0   /m/040rq70            /m/0jgrwlq
# 320117                  34.0   /m/02wk6hd              /m/01d5g
# 377615                  37.0   /m/02wk6dq              /m/01d5g
# 377796                  37.0    /m/0jv25f              /m/01d5g
# 399601                   NaN   /m/02tb9_k              /m/01d5g
# 438522                  35.0   /m/0hgtlkq            /m/0j6qr0b
# 439669                  33.0   /m/0h2kcl2              /m/01d5g
# 441236                  31.0   /m/02wk6gw              /m/01d5g
#
#        Freebase_Actor_ID
# 25371         /m/0g4f599
# 35948          /m/01yfm8
# 47853          /m/018yj6
# 63399          /m/09pgfj
# 63694          /m/01wy5m
# 81711          /m/04wp3s
# 94576           /m/0d_84
# 153462         /m/03s_sz
# 189697        /m/0gj68b4
# 231733         /m/06cddt
# 239783         /m/03s_sz
# 245835         /m/09br2g
# 292904         /m/014zcr
# 293012         /m/01j5ws
# 312456         /m/01nwwl
# 320117         /m/01wy5m
# 377615         /m/01j5ws
# 377796         /m/01pm0_
# 399601         /m/01pm0_
# 438522        /m/047t1_c
# 439669         /m/02t244
# 441236         /m/01wy5m

# %%
pd.set_option("display.max_rows", 50, "display.max_columns", 50)
movies.dropna(subset=['Box_Office_Revenue']).sort_values(by=['Box_Office_Revenue'])
# Out:
#         Wiki_ID Freebase_ID                                           Name  \
# 35178  28223867  /m/07l4_10       Hugh Hefner: Playboy, Activist and Rebel
# 51695  29085210  /m/0dll0nz                                  GhettoPhysics
# 53942  33895664  /m/07k983r                                          Logan
# 31550  15904586  /m/03qfnkx                           Fighting Tommy Riley
# 56050  20122638  /m/04yft1h                              Frankie and Alice
# ...         ...         ...                                            ...
# 18645  25001260  /m/0872p_c                 Transformers: Dark of the Moon
# 30278  31941988  /m/0gvsynb  Harry Potter and the Deathly Hallows – Part 2
# 28192  22114132  /m/062zm5h                                   The Avengers
# 22256     52371    /m/0dr_4                                        Titanic
# 23702   4273140   /m/0bth54                                         Avatar
#
#       Release_Date  Box_Office_Revenue  Length  \
# 35178   2010-07-30        1.000000e+04   135.0
# 51695         2010        1.020000e+04     NaN
# 53942         2010        1.047400e+04     NaN
# 31550   2005-05-06        1.051400e+04   109.0
# 56050   2010-12-10        1.067000e+04   101.0
# ...            ...                 ...     ...
# 18645   2011-06-23        1.123747e+09   157.0
# 30278   2011-07-07        1.328111e+09   130.0
# 28192   2012-04-11        1.511758e+09   137.0
# 22256   1997-11-01        2.185372e+09   194.0
# 23702   2009-12-10        2.782275e+09   178.0
#
#                                                 language  \
# 35178                 {"/m/02h40lc": "English Language"}
# 51695                                                 {}
# 53942                                                 {}
# 31550                 {"/m/02h40lc": "English Language"}
# 56050                 {"/m/02h40lc": "English Language"}
# ...                                                  ...
# 18645                 {"/m/02h40lc": "English Language"}
# 30278                 {"/m/02h40lc": "English Language"}
# 28192  {"/m/06b_j": "Russian Language", "/m/02h40lc":...
# 22256  {"/m/02bjrlw": "Italian Language", "/m/02h40lc...
# 23702  {"/m/02h40lc": "English Language", "/m/06nm1":...
#
#                                                  Country  \
# 35178                            {"/m/0d060g": "Canada"}
# 51695                                                 {}
# 53942          {"/m/09c7w0": "United States of America"}
# 31550          {"/m/09c7w0": "United States of America"}
# 56050                            {"/m/0d060g": "Canada"}
# ...                                                  ...
# 18645          {"/m/09c7w0": "United States of America"}
# 30278  {"/m/09c7w0": "United States of America", "/m/...
# 28192          {"/m/09c7w0": "United States of America"}
# 22256          {"/m/09c7w0": "United States of America"}
# 23702  {"/m/09c7w0": "United States of America", "/m/...
#
#                                                    Genre
# 35178  {"/m/0hj3n07": "Culture & Society", "/m/017fp"...
# 51695  {"/m/0cshrf": "Political cinema", "/m/0jtdp": ...
# 53942  {"/m/0hqxf": "Family Film", "/m/07s9rl0": "Dra...
# 31550  {"/m/0hn10": "LGBT", "/m/01z02hx": "Sports", "...
# 56050   {"/m/017fp": "Biography", "/m/07s9rl0": "Drama"}
# ...                                                  ...
# 18645  {"/m/0hj3mt0": "Alien Film", "/m/06n90": "Scie...
# 30278  {"/m/07s9rl0": "Drama", "/m/02n4kr": "Mystery"...
# 28192  {"/m/06n90": "Science Fiction", "/m/02kdv5l": ...
# 22256  {"/m/0fx2s": "Tragedy", "/m/04xvh5": "Costume ...
# 23702  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
#
# [8401 rows x 9 columns]

# %%
characters[characters.Actor_Name=='Daniel Craig']
# Out:
#          Wiki_ID Freebase_ID Release_Date                 Name  \
# 10572    4972125   /m/0cxw2d   1998-09-16          George Dyer
# 23691     503161   /m/02j48l         2003           Ted Hughes
# 25311   11744739  /m/02rqx5y          NaN                  Ray
# 57877   15349469  /m/03m5vzd   2008-12-13        Tuvia Bielski
# 60438    7883438  /m/026hh0m   2007-08-17         Ben Driscoll
# 65462   11400848  /m/02rb84n   2011-10-23          Red Rackham
# 86180    1102360   /m/0464d7   2004-09-04                  Joe
# 91031    1572988   /m/05ch98   2005-01-23       Rudy Mackenzie
# 92422    8175804  /m/026v977   1993-05-12                Berry
# 105924   1044633   /m/0413tm   2004-10-01                 XXXX
# 113427    342741   /m/01y9r2   2002-07-12        Connor Rooney
# 116214  26252728  /m/0cc5mcj   2011-07-29        Jake Lonergan
# 126382  19068544  /m/04jm4c9         1998     James Lynchehaun
# 145037   1128444   /m/048qfd   2003-11-14               Darren
# 154489   6320176   /m/0g0wx7         1999  Sgt. Telford Winter
# 182499   2811692   /m/0847m1   2006-10-13          Perry Smith
# 185537  24416802  /m/07s6472         2000       Ronald Blanche
# 208414  21981842  /m/05p7w6k   1992-03-27           Sgt. Botha
# 215221   1355085   /m/04w7rn   2007-11-27          Lord Asriel
# 215295  12252836  /m/02vxq9m   2012-10-23           James Bond
# 242620  18608517  /m/09v84yn         2002    Werner Heisenberg
# 255191     49800    /m/0d6_s   2001-06-15            Alex West
# 270260   1693901   /m/05nyv3         1997           Guillaumet
# 274684  28387289  /m/0dgq_kn   2011-12-21     Mikael Blomkvist
# 282911  32358656   /m/039q43   2000-05-05      Declan Fielding
# 288745   2969247   /m/08gsvw   2008-10-29           James Bond
# 290781    930379   /m/03r0g9   2006-11-14           James Bond
# 298141  28224334  /m/0cn_srj   2011-09-30         Will Atenton
# 301869   2311219   /m/072x7s   2005-12-23                Steve
# 331835    286852   /m/01q41m   1995-08-11          Master Kane
# 364486   2422739   /m/07b_j6         2005     US Army Sergeant
# 374152    142461   /m/011yr9   1998-11-06         John Ballard
# 383718  16451841  /m/03y4nzy   2008-04-18       Adult Joe Scot
# 409944   4408863   /m/0c0pwb   2006-03-15     Barthélémy Karas
# 431834  27837500  /m/0g4p4s1         1997         John MacHale
#
#        Actor_Date_Of_Birth Actor_Gender  Actor_Height Actor_Ethnicity  \
# 10572           1968-03-02            M          1.78       /m/04_bc8
# 23691           1968-03-02            M          1.78       /m/04_bc8
# 25311           1968-03-02            M          1.78       /m/04_bc8
# 57877           1968-03-02            M          1.78       /m/04_bc8
# 60438           1968-03-02            M          1.78       /m/04_bc8
# 65462           1968-03-02            M          1.78       /m/04_bc8
# 86180           1968-03-02            M          1.78       /m/04_bc8
# 91031           1968-03-02            M          1.78       /m/04_bc8
# 92422           1968-03-02            M          1.78       /m/04_bc8
# 105924          1968-03-02            M          1.78       /m/04_bc8
# 113427          1968-03-02            M          1.78       /m/04_bc8
# 116214          1968-03-02            M          1.78       /m/04_bc8
# 126382          1968-03-02            M          1.78       /m/04_bc8
# 145037          1968-03-02            M          1.78       /m/04_bc8
# 154489          1968-03-02            M          1.78       /m/04_bc8
# 182499          1968-03-02            M          1.78       /m/04_bc8
# 185537          1968-03-02            M          1.78       /m/04_bc8
# 208414          1968-03-02            M          1.78       /m/04_bc8
# 215221          1968-03-02            M          1.78       /m/04_bc8
# 215295          1968-03-02            M          1.78       /m/04_bc8
# 242620          1968-03-02            M          1.78       /m/04_bc8
# 255191          1968-03-02            M          1.78       /m/04_bc8
# 270260          1968-03-02            M          1.78       /m/04_bc8
# 274684          1968-03-02            M          1.78       /m/04_bc8
# 282911          1968-03-02            M          1.78       /m/04_bc8
# 288745          1968-03-02            M          1.78       /m/04_bc8
# 290781          1968-03-02            M          1.78       /m/04_bc8
# 298141          1968-03-02            M          1.78       /m/04_bc8
# 301869          1968-03-02            M          1.78       /m/04_bc8
# 331835          1968-03-02            M          1.78       /m/04_bc8
# 364486          1968-03-02            M          1.78       /m/04_bc8
# 374152          1968-03-02            M          1.78       /m/04_bc8
# 383718          1968-03-02            M          1.78       /m/04_bc8
# 409944          1968-03-02            M          1.78       /m/04_bc8
# 431834          1968-03-02            M          1.78       /m/04_bc8
#
#           Actor_Name  Actor_Age_At_Release Freebase_Map Freebase_Character_ID  \
# 10572   Daniel Craig                  30.0   /m/0gx91m5            /m/0lqs03w
# 23691   Daniel Craig                  34.0    /m/0k40td            /m/02nw8sw
# 25311   Daniel Craig                   NaN   /m/02vd0wb            /m/0gx91h_
# 57877   Daniel Craig                  40.0   /m/040nkxv            /m/0dh092w
# 60438   Daniel Craig                  39.0   /m/02h7bc8            /m/0hmzlq7
# 65462   Daniel Craig                  43.0   /m/05nr38z             /m/0d1b78
# 86180   Daniel Craig                  36.0    /m/0jxw1j            /m/0bky8jg
# 91031   Daniel Craig                  36.0    /m/0k5hy9            /m/0c1q1md
# 92422   Daniel Craig                  25.0   /m/0gx91x2            /m/0gx91x4
# 105924  Daniel Craig                  36.0    /m/0j_tjq            /m/03x15dz
# 113427  Daniel Craig                  34.0    /m/0k2ljz            /m/0bd6cvc
# 116214  Daniel Craig                  43.0   /m/0bq7lwg            /m/0bq7lw4
# 126382  Daniel Craig                  29.0   /m/04j2w5z            /m/0gx91kf
# 145037  Daniel Craig                  35.0    /m/0k5ynj            /m/0gx91h8
# 154489  Daniel Craig                  30.0   /m/03js842            /m/0gx91l1
# 182499  Daniel Craig                  38.0   /m/03jrs92            /m/0cvbctk
# 185537  Daniel Craig                  31.0   /m/0ggdh0r            /m/0gx91hs
# 208414  Daniel Craig                  24.0   /m/0gx91zw            /m/0gx91zy
# 215221  Daniel Craig                  39.0   /m/02vbblr             /m/03hfqb
# 215295  Daniel Craig                  44.0   /m/0gwhydl             /m/0clpml
# 242620  Daniel Craig                  33.0   /m/09vnmny            /m/0fprnrs
# 255191  Daniel Craig                  33.0   /m/02tbd5z            /m/0cm6937
# 270260  Daniel Craig                  28.0   /m/0gx91s4            /m/0gx91s6
# 274684  Daniel Craig                  43.0   /m/0cv8jyw            /m/0c01td_
# 282911  Daniel Craig                  32.0   /m/04q5_xq            /m/0cqs_yz
# 288745  Daniel Craig                  40.0   /m/03hqwg_             /m/0clpml
# 290781  Daniel Craig                  38.0   /m/02hw79s             /m/0clpml
# 298141  Daniel Craig                  43.0   /m/0gw57z9            /m/0gw51m4
# 301869  Daniel Craig                  37.0    /m/0k0yjz            /m/0gct6p3
# 331835  Daniel Craig                  27.0    /m/0jssg1            /m/0gx91v2
# 364486  Daniel Craig                  36.0   /m/0gx91gx            /m/0gx91gz
# 374152  Daniel Craig                  30.0   /m/02vbxj6            /m/0gx91lz
# 383718  Daniel Craig                  40.0   /m/04dgb7k            /m/0gx91fr
# 409944  Daniel Craig                  38.0   /m/03jp9vn            /m/0gx91g1
# 431834  Daniel Craig                  28.0   /m/0ccf42h            /m/0gx91lr
#
#        Freebase_Actor_ID
# 10572          /m/04shbh
# 23691          /m/04shbh
# 25311          /m/04shbh
# 57877          /m/04shbh
# 60438          /m/04shbh
# 65462          /m/04shbh
# 86180          /m/04shbh
# 91031          /m/04shbh
# 92422          /m/04shbh
# 105924         /m/04shbh
# 113427         /m/04shbh
# 116214         /m/04shbh
# 126382         /m/04shbh
# 145037         /m/04shbh
# 154489         /m/04shbh
# 182499         /m/04shbh
# 185537         /m/04shbh
# 208414         /m/04shbh
# 215221         /m/04shbh
# 215295         /m/04shbh
# 242620         /m/04shbh
# 255191         /m/04shbh
# 270260         /m/04shbh
# 274684         /m/04shbh
# 282911         /m/04shbh
# 288745         /m/04shbh
# 290781         /m/04shbh
# 298141         /m/04shbh
# 301869         /m/04shbh
# 331835         /m/04shbh
# 364486         /m/04shbh
# 374152         /m/04shbh
# 383718         /m/04shbh
# 409944         /m/04shbh
# 431834         /m/04shbh

# %%
convert = pd.read_csv('fb2w.nt', sep=" ")
# Out:
# /var/folders/yv/q6fl_nv53dv6l2kfbv_6jc680000gn/T/ipykernel_48518/2487994969.py:1: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   convert = pd.read_csv('fb2w.nt', sep=" ")

# %%
convert
# Out:
#                                                          #    Mapping     of  \
# 0                                                        #  Published  under
# 1                                                        #  Published     by
# 2        <http://rdf.freebase.com/ns/m.0695j>\t<http://...          .    NaN
# 3        <http://rdf.freebase.com/ns/m.05nrg>\t<http://...          .    NaN
# 4        <http://rdf.freebase.com/ns/m.0jgd>\t<http://w...          .    NaN
# ...                                                    ...        ...    ...
# 2099579  <http://rdf.freebase.com/ns/m.04mzslb>\t<http:...          .    NaN
# 2099580  <http://rdf.freebase.com/ns/m.05zx856>\t<http:...          .    NaN
# 2099581  <http://rdf.freebase.com/ns/m.0cc5zk5>\t<http:...          .    NaN
# 2099582  <http://rdf.freebase.com/ns/m.02x3sv_>\t<http:...          .    NaN
# 2099583  <http://rdf.freebase.com/ns/m.0h65lc7>\t<http:...          .    NaN
#
#         Freebase                                           entities      to  \
# 0            CC0  http://creativecommons.org/publicdomain/zero/1.0/     NaN
# 1        Google,                                           November  2013.0
# 2            NaN                                                NaN     NaN
# 3            NaN                                                NaN     NaN
# 4            NaN                                                NaN     NaN
# ...          ...                                                ...     ...
# 2099579      NaN                                                NaN     NaN
# 2099580      NaN                                                NaN     NaN
# 2099581      NaN                                                NaN     NaN
# 2099582      NaN                                                NaN     NaN
# 2099583      NaN                                                NaN     NaN
#
#          Wikidata  entities.1
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# ...           ...         ...
# 2099579       NaN         NaN
# 2099580       NaN         NaN
# 2099581       NaN         NaN
# 2099582       NaN         NaN
# 2099583       NaN         NaN
#
# [2099584 rows x 8 columns]

# %%
convert = convert[2:]

# %%
convert = pd.DataFrame(convert['#'])

# %%
convert
# Out:
#                                                          #
# 2        <http://rdf.freebase.com/ns/m.0695j>\t<http://...
# 3        <http://rdf.freebase.com/ns/m.05nrg>\t<http://...
# 4        <http://rdf.freebase.com/ns/m.0jgd>\t<http://w...
# 5        <http://rdf.freebase.com/ns/m.0d_23>\t<http://...
# 6        <http://rdf.freebase.com/ns/m.04g7d>\t<http://...
# ...                                                    ...
# 2099579  <http://rdf.freebase.com/ns/m.04mzslb>\t<http:...
# 2099580  <http://rdf.freebase.com/ns/m.05zx856>\t<http:...
# 2099581  <http://rdf.freebase.com/ns/m.0cc5zk5>\t<http:...
# 2099582  <http://rdf.freebase.com/ns/m.02x3sv_>\t<http:...
# 2099583  <http://rdf.freebase.com/ns/m.0h65lc7>\t<http:...
#
# [2099582 rows x 1 columns]

# %%
convert[['freebase','w3','wikidata']] = convert['#'].str.split("\t",expand=True,)

# %%
convert
# Out:
#                                                          #  \
# 2        <http://rdf.freebase.com/ns/m.0695j>\t<http://...
# 3        <http://rdf.freebase.com/ns/m.05nrg>\t<http://...
# 4        <http://rdf.freebase.com/ns/m.0jgd>\t<http://w...
# 5        <http://rdf.freebase.com/ns/m.0d_23>\t<http://...
# 6        <http://rdf.freebase.com/ns/m.04g7d>\t<http://...
# ...                                                    ...
# 2099579  <http://rdf.freebase.com/ns/m.04mzslb>\t<http:...
# 2099580  <http://rdf.freebase.com/ns/m.05zx856>\t<http:...
# 2099581  <http://rdf.freebase.com/ns/m.0cc5zk5>\t<http:...
# 2099582  <http://rdf.freebase.com/ns/m.02x3sv_>\t<http:...
# 2099583  <http://rdf.freebase.com/ns/m.0h65lc7>\t<http:...
#
#                                        freebase  \
# 2          <http://rdf.freebase.com/ns/m.0695j>
# 3          <http://rdf.freebase.com/ns/m.05nrg>
# 4           <http://rdf.freebase.com/ns/m.0jgd>
# 5          <http://rdf.freebase.com/ns/m.0d_23>
# 6          <http://rdf.freebase.com/ns/m.04g7d>
# ...                                         ...
# 2099579  <http://rdf.freebase.com/ns/m.04mzslb>
# 2099580  <http://rdf.freebase.com/ns/m.05zx856>
# 2099581  <http://rdf.freebase.com/ns/m.0cc5zk5>
# 2099582  <http://rdf.freebase.com/ns/m.02x3sv_>
# 2099583  <http://rdf.freebase.com/ns/m.0h65lc7>
#
#                                              w3  \
# 2        <http://www.w3.org/2002/07/owl#sameAs>
# 3        <http://www.w3.org/2002/07/owl#sameAs>
# 4        <http://www.w3.org/2002/07/owl#sameAs>
# 5        <http://www.w3.org/2002/07/owl#sameAs>
# 6        <http://www.w3.org/2002/07/owl#sameAs>
# ...                                         ...
# 2099579  <http://www.w3.org/2002/07/owl#sameAs>
# 2099580  <http://www.w3.org/2002/07/owl#sameAs>
# 2099581  <http://www.w3.org/2002/07/owl#sameAs>
# 2099582  <http://www.w3.org/2002/07/owl#sameAs>
# 2099583  <http://www.w3.org/2002/07/owl#sameAs>
#
#                                            wikidata
# 2            <http://www.wikidata.org/entity/Q6718>
# 3             <http://www.wikidata.org/entity/Q538>
# 4             <http://www.wikidata.org/entity/Q414>
# 5            <http://www.wikidata.org/entity/Q2537>
# 6             <http://www.wikidata.org/entity/Q315>
# ...                                             ...
# 2099579  <http://www.wikidata.org/entity/Q11754906>
# 2099580  <http://www.wikidata.org/entity/Q10543247>
# 2099581   <http://www.wikidata.org/entity/Q1361612>
# 2099582   <http://www.wikidata.org/entity/Q4697097>
# 2099583   <http://www.wikidata.org/entity/Q5444866>
#
# [2099582 rows x 4 columns]

# %%
convert = convert[['freebase','wikidata']]

# %%
convert
# Out:
#                                        freebase  \
# 2          <http://rdf.freebase.com/ns/m.0695j>
# 3          <http://rdf.freebase.com/ns/m.05nrg>
# 4           <http://rdf.freebase.com/ns/m.0jgd>
# 5          <http://rdf.freebase.com/ns/m.0d_23>
# 6          <http://rdf.freebase.com/ns/m.04g7d>
# ...                                         ...
# 2099579  <http://rdf.freebase.com/ns/m.04mzslb>
# 2099580  <http://rdf.freebase.com/ns/m.05zx856>
# 2099581  <http://rdf.freebase.com/ns/m.0cc5zk5>
# 2099582  <http://rdf.freebase.com/ns/m.02x3sv_>
# 2099583  <http://rdf.freebase.com/ns/m.0h65lc7>
#
#                                            wikidata
# 2            <http://www.wikidata.org/entity/Q6718>
# 3             <http://www.wikidata.org/entity/Q538>
# 4             <http://www.wikidata.org/entity/Q414>
# 5            <http://www.wikidata.org/entity/Q2537>
# 6             <http://www.wikidata.org/entity/Q315>
# ...                                             ...
# 2099579  <http://www.wikidata.org/entity/Q11754906>
# 2099580  <http://www.wikidata.org/entity/Q10543247>
# 2099581   <http://www.wikidata.org/entity/Q1361612>
# 2099582   <http://www.wikidata.org/entity/Q4697097>
# 2099583   <http://www.wikidata.org/entity/Q5444866>
#
# [2099582 rows x 2 columns]

# %%
def stringfreebase(x):
    x = x[27:]
    x = x.replace('.','/')
    x = x.replace('>','')
    return x

# %%
def stringwikidata(x):
    x = x[32:]
    x = x.replace('>','')
    return x

# %%
table = pd.DataFrame(convert['freebase'].apply(stringfreebase))
table
# Out:
#            freebase
# 2          /m/0695j
# 3          /m/05nrg
# 4           /m/0jgd
# 5          /m/0d_23
# 6          /m/04g7d
# ...             ...
# 2099579  /m/04mzslb
# 2099580  /m/05zx856
# 2099581  /m/0cc5zk5
# 2099582  /m/02x3sv_
# 2099583  /m/0h65lc7
#
# [2099582 rows x 1 columns]

# %%
table['wiki'] = convert['wikidata'].apply(stringwikidata)
table
# Out:
#            freebase       wiki
# 2          /m/0695j      Q6718
# 3          /m/05nrg       Q538
# 4           /m/0jgd       Q414
# 5          /m/0d_23      Q2537
# 6          /m/04g7d       Q315
# ...             ...        ...
# 2099579  /m/04mzslb  Q11754906
# 2099580  /m/05zx856  Q10543247
# 2099581  /m/0cc5zk5   Q1361612
# 2099582  /m/02x3sv_   Q4697097
# 2099583  /m/0h65lc7   Q5444866
#
# [2099582 rows x 2 columns]

# %%
movies = movies.merge(table, left_on='Freebase_ID', right_on='freebase')
movies
# Out:
#         Wiki_ID Freebase_ID  \
# 0        975900   /m/03vyhn
# 1      28463795  /m/0crgdbh
# 2        261236   /m/01mrr1
# 3      13696889  /m/03cfc81
# 4      18998739  /m/04jcqvw
# ...         ...         ...
# 45422  23851782  /m/06_vb43
# 45423  12095128  /m/02vppbd
# 45424  32468537  /m/0crwd9y
# 45425  35228177  /m/0j7hxnt
# 45426    913762   /m/03pcrp
#
#                                                     Name Release_Date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1                                            Brun bitter         1988
# 2                                      A Woman in Flames         1983
# 3                                          The Gangsters   1913-05-29
# 4                              The Sorcerer's Apprentice         2002
# ...                                                  ...          ...
# 45422                                    The Ghost Train   1941-05-03
# 45423                                            My Love          NaN
# 45424                                    Shadow Boxing 2   2007-10-18
# 45425                           Mermaids: The Body Found   2011-03-19
# 45426  The Super Dimension Fortress Macross II: Lover...   1992-05-21
#
#        Box_Office_Revenue  Length  \
# 0              14010832.0    98.0
# 1                     NaN    83.0
# 2                     NaN   106.0
# 3                     NaN    35.0
# 4                     NaN    86.0
# ...                   ...     ...
# 45422                 NaN    82.0
# 45423                 NaN    26.0
# 45424                 NaN   132.0
# 45425                 NaN   120.0
# 45426                 NaN   150.0
#
#                                                 language  \
# 0                     {"/m/02h40lc": "English Language"}
# 1                     {"/m/05f_3": "Norwegian Language"}
# 2                      {"/m/04306rv": "German Language"}
# 3      {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
# 4                     {"/m/02h40lc": "English Language"}
# ...                                                  ...
# 45422                 {"/m/02h40lc": "English Language"}
# 45423                   {"/m/06b_j": "Russian Language"}
# 45424  {"/m/06b_j": "Russian Language", "/m/02h40lc":...
# 45425                 {"/m/02h40lc": "English Language"}
# 45426                  {"/m/03_9r": "Japanese Language"}
#
#                                          Country  \
# 0      {"/m/09c7w0": "United States of America"}
# 1                         {"/m/05b4w": "Norway"}
# 2                        {"/m/0345h": "Germany"}
# 3      {"/m/09c7w0": "United States of America"}
# 4                   {"/m/0hzlz": "South Africa"}
# ...                                          ...
# 45422             {"/m/07ssc": "United Kingdom"}
# 45423                     {"/m/06bnz": "Russia"}
# 45424                     {"/m/06bnz": "Russia"}
# 45425  {"/m/09c7w0": "United States of America"}
# 45426                      {"/m/03_3d": "Japan"}
#
#                                                    Genre    freebase      wiki
# 0      {"/m/01jfsb": "Thriller", "/m/06n90": "Science...   /m/03vyhn   Q261700
# 1      {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...  /m/0crgdbh  Q4978832
# 2                                {"/m/07s9rl0": "Drama"}   /m/01mrr1   Q869644
# 3      {"/m/02hmvc": "Short Film", "/m/06ppq": "Silen...  /m/03cfc81  Q3067285
# 4      {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...  /m/04jcqvw  Q7765318
# ...                                                  ...         ...       ...
# 45422  {"/m/0lsxr": "Crime Fiction", "/m/01jfsb": "Th...  /m/06_vb43  Q7736298
# 45423                        {"/m/02hmvc": "Short Film"}  /m/02vppbd  Q1700355
# 45424  {"/m/01z02hx": "Sports", "/m/0lsxr": "Crime Fi...  /m/0crwd9y   Q965863
# 45425                            {"/m/07s9rl0": "Drama"}  /m/0j7hxnt  Q6819873
# 45426  {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...   /m/03pcrp  Q2663931
#
# [45427 rows x 11 columns]

# %%
from qwikidata.entity import WikidataItem, WikidataLexeme, WikidataProperty
from qwikidata.linked_data_interface import get_entity_dict_from_api

# %%
from wikidata.client import Client

# %%
client = Client()
entity = client.get('Q965863', load=True)

# %%
entity
# Out:
# <wikidata.entity.Entity Q965863 'Shadowboxing 2: Revenge'>

# %%
spouse_prop = client.get('P1651')
spouse_prop = entity[spouse_prop]
spouse_prop
# Out:
# 'avho1TREQ8o'

# %% [markdown]
# from wikidata.client import Client
# client = Client()
# entity = client.get('Q39829', load=True)
#
# Spouse
# spouse_prop = client.get('P26')
# spouse = entity[spouse_prop]
# print('Mother: ', spouse.label)
#
# Children
# child_prop = client.get('P40')
# child = entity[child_prop]
# print('Children: ', dir(child))
# print(child.label)

# %%
movies[movies.Name == 'Iron Man']
# Out:
#         Wiki_ID Freebase_ID      Name Release_Date  Box_Office_Revenue  \
# 21205  17367782  /m/043plhx  Iron Man   1931-04-30                 NaN
# 25975   5676692   /m/0dzlbx  Iron Man   2008-04-14         585174222.0
#
#        Length                                           language  \
# 21205    73.0                 {"/m/02h40lc": "English Language"}
# 25975   126.0  {"/m/032f6": "Persian Language", "/m/0jzc": "A...
#
#                                          Country  \
# 21205  {"/m/09c7w0": "United States of America"}
# 25975  {"/m/09c7w0": "United States of America"}
#
#                                                    Genre    freebase      wiki
# 21205  {"/m/07s9rl0": "Drama", "/m/087lqx": "Pre-Code...  /m/043plhx  Q1758603
# 25975  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...   /m/0dzlbx   Q192724

# %%
client = Client()
entity = client.get('Q192724', load=True)

# %%
spouse_prop = client.get('P444')
spouse_prop = entity[spouse_prop]
spouse_prop
# Out:
# '79/100'

# %%
entity
# Out:
# <wikidata.entity.Entity Q192724 'Iron Man'>

# %%
from wikidata2df import wikidata2df

cat_query = """
#Cats
SELECT ?item ?itemLabel
WHERE
{
# ?item wdt:P31 wd:Q146.
SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""

cats_dataframe = wikidata2df(cat_query)

# %%
cats_dataframe
# Out:
#                    itemLabel        item
# 0                         CC     Q378619
# 1                     Muezza     Q498787
# 2                    Orangey     Q677525
# 3                Mrs. Chippy     Q851190
# 4             Unsinkable Sam     Q893453
# ..                       ...         ...
# 154                    Jorts  Q110565455
# 155                   Willow  Q110727478
# 156  the cat from Borodianka  Q112152493
# 157               11 kitties  Q113512285
# 158                      Gli  Q114569446
#
# [159 rows x 2 columns]

# %%
from wikidata2df import wikidata2df

cat_query = """
#Cats
SELECT ?item wdt:P577 wd:Q192724.
"""

cats_dataframe = wikidata2df(cat_query)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wikidata2df/wikidata2df.py:33, in perform_query(query)
#      28     response = requests.get(
#      29         endpoint_url,
#      30         params={"query": query},
#      31         headers={"Accept": "application/sparql-results+json"},
#      32     )
# ---> 33     response.raise_for_status()
#      35 except requests.exceptions.HTTPError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://query.wikidata.org/sparql?query=%0A%23Cats%0ASELECT+%3Fitem+wdt%3AP577+wd%3AQ192724.%0A
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In [43], line 8
#       1 from wikidata2df import wikidata2df
#       3 cat_query = """
#       4 #Cats
#       5 SELECT ?item wdt:P577 wd:Q192724.
#       6 """
# ----> 8 cats_dataframe = wikidata2df(cat_query)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wikidata2df/wikidata2df.py:90, in wikidata2df(query)
#      74 @lru_cache(maxsize=10)
#      75 def wikidata2df(query):
#      76     """Transform a wikidata SPARQL query into a Pandas DataFrame
#      77
#      78     Wrapper function that performs a request to the wikidata endpoint and returns a dataframe.
#    (...)
#      87         A Pandas DataFrame with the results of the query.
#      88     """
# ---> 90     query_res = perform_query(query)
#      92     parsed_res = parse_query_results(query_res)
#      94     return parsed_res
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wikidata2df/wikidata2df.py:36, in perform_query(query)
#      33     response.raise_for_status()
#      35 except requests.exceptions.HTTPError as err:
# ---> 36     raise requests.exceptions.HTTPError(err)
#      38 else:
#      39     raw_results = response.json()
#
# HTTPError: 400 Client Error: Bad Request for url: https://query.wikidata.org/sparql?query=%0A%23Cats%0ASELECT+%3Fitem+wdt%3AP577+wd%3AQ192724.%0A

# %%
client = Client()
entity = client.get('Q192724', load=True)
spouse_prop = client.get('577')
spouse_prop = entity[spouse_prop]
spouse_prop
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [44], line 4
#       2 entity = client.get('Q192724', load=True)
#       3 spouse_prop = client.get('577')
# ----> 4 spouse_prop = entity[spouse_prop]
#       5 spouse_prop
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wikidata/entity.py:179, in Entity.__getitem__(self, key)
#     178 def __getitem__(self, key: 'Entity') -> object:
# --> 179     result = self.getlist(key)
#     180     if result:
#     181         return result[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wikidata/entity.py:197, in Entity.getlist(self, key)
#     184 def getlist(self, key: 'Entity') -> Sequence[object]:
#     185     r"""Return all values associated to the given ``key`` property
#     186     in sequence.
#     187
#    (...)
#     194
#     195     """
#     196     if not (isinstance(key, type(self)) and
# --> 197             key.type is EntityType.property):
#     198         return []
#     199     claims_map = self.attributes.get('claims') or {}
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wikidata/entity.py:247, in Entity.type(self)
#     245         return guessed_type
#     246     # If guessing was failed follow the straightforward way.
# --> 247 return EntityType(self.attributes['type'])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wikidata/entity.py:253, in Entity.attributes(self)
#     251 if self.data is None:
#     252     self.load()
# --> 253 assert self.data is not None
#     254 return self.data
#
# AssertionError:

# %%
film_query = """
SELECT ?item ?itemLabel
WHERE {
SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE]". }
{
SELECT DISTINCT ?item WHERE {
# ?item p:P444 ?statement0.
# ?statement0 (ps:P444) _:anyValueP444.
# ?item p:P31 ?statement1.
# ?statement1 (ps:P31/(wdt:P279*)) wd:Q11424.
}
}
}
"""

# %%
film_df = wikidata2df(film_query)

# %%
film_df
# Out:
#        itemLabel       item
# 0        Q253566    Q253566
# 1        Q253565    Q253565
# 2        Q255328    Q255328
# 3        Q255376    Q255376
# 4        Q259332    Q259332
# ...          ...        ...
# 24543  Q29344687  Q29344687
# 24544  Q29363978  Q29363978
# 24545  Q29388552  Q29388552
# 24546  Q29391000  Q29391000
# 24547  Q29466808  Q29466808
#
# [24548 rows x 2 columns]

# %%
mergedall = movies.merge(film_df,left_on='wiki',right_on='item')
mergedall = mergedall.drop(columns=['item','itemLabel','freebase'])
mergedall
# Out:
#         Wiki_ID Freebase_ID                             Name Release_Date  \
# 0        975900   /m/03vyhn                   Ghosts of Mars   2001-08-24
# 1      10408933  /m/02qc0j7         Alexander's Ragtime Band   1938-08-16
# 2       2345652   /m/075f66                 City of the Dead         1960
# 3        171005   /m/016ywb                          Henry V   1989-11-08
# 4         77856    /m/0kcn7                     Mary Poppins   1964-08-27
# ...         ...         ...                              ...          ...
# 13337     54540    /m/0f7hw                Coming to America   1988-06-29
# 13338   1673588   /m/05mc7l  The Brother from Another Planet   1984-09-07
# 13339   7761830   /m/0kvgqb                  Spaced Invaders         1990
# 13340   1918494   /m/0660qx                   State and Main   2000-08-26
# 13341    664006   /m/030xw6                    Guilty as Sin   1993-06-04
#
#        Box_Office_Revenue  Length  \
# 0              14010832.0    98.0
# 1               3600000.0   106.0
# 2                     NaN    76.0
# 3              10161099.0   137.0
# 4             102272727.0   139.0
# ...                   ...     ...
# 13337         288752301.0   117.0
# 13338                 NaN   104.0
# 13339          15369573.0   100.0
# 13340           6944471.0   106.0
# 13341          22886222.0   107.0
#
#                                                 language  \
# 0                     {"/m/02h40lc": "English Language"}
# 1                     {"/m/02h40lc": "English Language"}
# 2                     {"/m/02h40lc": "English Language"}
# 3                     {"/m/02h40lc": "English Language"}
# 4                     {"/m/02h40lc": "English Language"}
# ...                                                  ...
# 13337                 {"/m/02h40lc": "English Language"}
# 13338  {"/m/02h40lc": "English Language", "/m/06nm1":...
# 13339                 {"/m/02h40lc": "English Language"}
# 13340  {"/m/02bjrlw": "Italian Language", "/m/02h40lc...
# 13341                                                 {}
#
#                                                  Country  \
# 0              {"/m/09c7w0": "United States of America"}
# 1              {"/m/09c7w0": "United States of America"}
# 2                         {"/m/07ssc": "United Kingdom"}
# 3                         {"/m/07ssc": "United Kingdom"}
# 4              {"/m/09c7w0": "United States of America"}
# ...                                                  ...
# 13337          {"/m/09c7w0": "United States of America"}
# 13338          {"/m/09c7w0": "United States of America"}
# 13339          {"/m/09c7w0": "United States of America"}
# 13340  {"/m/0f8l9c": "France", "/m/09c7w0": "United S...
# 13341          {"/m/09c7w0": "United States of America"}
#
#                                                    Genre      wiki
# 0      {"/m/01jfsb": "Thriller", "/m/06n90": "Science...   Q261700
# 1      {"/m/04t36": "Musical", "/m/01z4y": "Comedy", ...  Q1619977
# 2      {"/m/03npn": "Horror", "/m/0fdjb": "Supernatur...   Q194106
# 3      {"/m/04xvh5": "Costume drama", "/m/082gq": "Wa...   Q114115
# 4      {"/m/0hj3myq": "Children's/Family", "/m/04t36"...   Q209170
# ...                                                  ...       ...
# 13337  {"/m/06cvj": "Romantic comedy", "/m/03p5xs": "...   Q493755
# 13338  {"/m/06n90": "Science Fiction", "/m/0219x_": "...   Q955416
# 13339  {"/m/0hj3mt0": "Alien Film", "/m/06n90": "Scie...  Q1320234
# 13340  {"/m/0gf28": "Parody", "/m/09n5t_": "Americana...   Q960668
# 13341  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...   Q387868
#
# [13342 rows x 10 columns]

# %%
def getdata(x):
    client = Client()
    entity = client.get(x, load=True)
    spouse_prop = client.get('P444')
    spouse_prop = entity[spouse_prop]
    return spouse_prop

# %%
mergedall['score'] = mergedall.wiki.apply(getdata)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [82], line 1
# ----> 1 mergedall['score'] = mergedall.wiki.apply(getdata)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# -> 1105 return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/apply.py:1156, in SeriesApply.apply_standard(self)
#    1154     else:
#    1155         values = obj.astype(object)._values
# -> 1156         mapped = lib.map_infer(
#    1157             values,
#    1158             f,
#    1159             convert=self.convert_dtype,
#    1160         )
#    1162 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1163     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1164     #  See also GH#25959 regarding EA support
#    1165     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2918, in pandas._libs.lib.map_infer()
#
# Cell In [81], line 3, in getdata(x)
#       1 def getdata(x):
#       2     client = Client()
# ----> 3     entity = client.get(x, load=True)
#       4     spouse_prop = client.get('P444')
#       5     spouse_prop = entity[spouse_prop]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wikidata/client.py:140, in Client.get(self, entity_id, load)
#     138     self.identity_map[entity_id] = entity
#     139 if load:
# --> 140     entity.load()
#     141 return entity
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wikidata/entity.py:261, in Entity.load(self)
#     258     return
#     260 url = './wiki/Special:EntityData/{}.json'.format(self.id)
# --> 261 result = self.client.request(url)
#     262 if result is None:
#     263     self.state = EntityState.non_existent
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wikidata/client.py:194, in Client.request(self, path)
#     192 logger.debug('%r: no cache; make a request...', url)
#     193 try:
# --> 194     response = self.opener.open(url)
#     195 except urllib.error.HTTPError as e:
#     196     logger.debug('HTTP error code: %s', e.code, exc_info=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#    1354     h.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
mergedtest = mergedall.sample(10)
mergedtest['score'] = mergedtest.wiki.apply(getdata)
mergedtest
# Out:
#        Wiki_ID Freebase_ID                 Name Release_Date  \
# 2818   9900396  /m/02pwcp_         Executioners   1993-09-30
# 200    5876575   /m/0fb9lq                   K2         1992
# 3820    292956   /m/01qv2_          The Manxman   1929-12-06
# 907     176545   /m/017yv4     The Seventh Seal   1957-02-16
# 7161   3406838   /m/099wbj  The Thief of Bagdad   1940-12-05
# 1021   3463364   /m/09dv8h  High School Musical   2006-01-20
# 2031   9597495  /m/02plbgx          Auntie Mame   1958-12-27
# 9591  16839388  /m/0407yj_               Cars 2   2011-06-18
# 243   20629940  /m/051zpx6    Not Easily Broken   2009-01-09
# 5624   2337281   /m/074r6w         Fast Company   1979-03-18
#
#       Box_Office_Revenue  Length  \
# 2818                 NaN    97.0
# 200            3043000.0   104.0
# 3820                 NaN    90.0
# 907                  NaN    96.0
# 7161                 NaN   106.0
# 1021                 NaN    97.0
# 2031                 NaN   143.0
# 9591         559852396.0   106.0
# 243           10708890.0   100.0
# 5624                 NaN    90.0
#
#                                                language  \
# 2818                         {"/m/012w70": "Cantonese"}
# 200                  {"/m/02h40lc": "English Language"}
# 3820  {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
# 907   {"/m/06mp7": "Swedish Language", "/m/04h9h": "...
# 7161                 {"/m/02h40lc": "English Language"}
# 1021  {"/m/02h40lc": "English Language", "/m/06nm1":...
# 2031                 {"/m/02h40lc": "English Language"}
# 9591  {"/m/064_8sq": "French Language", "/m/03_9r": ...
# 243                  {"/m/02h40lc": "English Language"}
# 5624                 {"/m/02h40lc": "English Language"}
#
#                                                 Country  \
# 2818                          {"/m/03h64": "Hong Kong"}
# 200                      {"/m/07ssc": "United Kingdom"}
# 3820                     {"/m/07ssc": "United Kingdom"}
# 907                             {"/m/0d0vqn": "Sweden"}
# 7161  {"/m/09c7w0": "United States of America", "/m/...
# 1021          {"/m/09c7w0": "United States of America"}
# 2031          {"/m/09c7w0": "United States of America"}
# 9591          {"/m/09c7w0": "United States of America"}
# 243           {"/m/09c7w0": "United States of America"}
# 5624                            {"/m/0d060g": "Canada"}
#
#                                                   Genre    freebase      wiki  \
# 2818  {"/m/03q4nz": "World cinema", "/m/04pbhw": "Su...  /m/02pwcp_   Q245815
# 200   {"/m/03btsm8": "Action/Adventure", "/m/01z02hx...   /m/0fb9lq  Q1718337
# 3820  {"/m/06ppq": "Silent film", "/m/07s9rl0": "Dra...   /m/01qv2_  Q1195706
# 907   {"/m/02n4lw": "Art film", "/m/03q4nz": "World ...   /m/017yv4   Q217189
# 7161  {"/m/03k9fj": "Adventure", "/m/04xvh5": "Costu...   /m/099wbj   Q463716
# 1021  {"/m/06cvj": "Romantic comedy", "/m/02h8pkk": ...   /m/09dv8h    Q53110
# 2031  {"/m/07s9rl0": "Drama", "/m/01z4y": "Comedy", ...  /m/02plbgx  Q1219582
# 9591  {"/m/03k9fj": "Adventure", "/m/0hj3myq": "Chil...  /m/0407yj_   Q192212
# 243   {"/m/0fx2s": "Tragedy", "/m/07s9rl0": "Drama",...  /m/051zpx6  Q7062066
# 5624  {"/m/01z02hx": "Sports", "/m/017fp": "Biograph...   /m/074r6w   Q163896
#
#      itemLabel      item score
# 2818   Q245815   Q245815   80%
# 200   Q1718337  Q1718337   29%
# 3820  Q1195706  Q1195706   92%
# 907    Q217189   Q217189   94%
# 7161   Q463716   Q463716  100%
# 1021    Q53110    Q53110   65%
# 2031  Q1219582  Q1219582   93%
# 9591   Q192212   Q192212   40%
# 243   Q7062066  Q7062066   31%
# 5624   Q163896   Q163896   88%

# %%
SELECT DISTINCT ?item ?itemLabel WHERE {
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE]". }
  {
    SELECT DISTINCT ?item WHERE {
      # ?item p:P444 ?statement0.
      # ?statement0 (ps:P444) _:anyValueP444.
      # ?item p:P31 ?statement1.
      # ?statement1 (ps:P31/(wdt:P279*)) wd:Q11424.
    }
  }
}

# %%
import pywikibot

# %%
site = pywikibot.Site("wikidata", "wikidata")
repo = site.data_repository()
item = pywikibot.ItemPage(repo, "Q42")

# %%
site = pywikibot.Site("en", "wikipedia")
page = pywikibot.Page(site, "Douglas Adams")
item = pywikibot.ItemPage.fromPage(page)

print(item)
# Out:
# [[wikidata:Q42]]
